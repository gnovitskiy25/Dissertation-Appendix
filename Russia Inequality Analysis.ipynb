# %% [markdown]
# # 1. Importing Libaries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import numpy as np
# %matplotlib inline

# %% [markdown]
# # 2. Reading Data

# %%
c_i = pd.read_csv("/Users/lorenzmaresca/Desktop/Greg/GregDiss/Data/WealthIncome/capital_income.csv")
avg_income_total = pd.read_csv("/Users/lorenzmaresca/Desktop/Greg/GregDiss/Data/WealthIncome/Income Avg.csv")
avg_income_total_2 = pd.read_csv("/Users/lorenzmaresca/Desktop/Greg/GregDiss/Data/WealthIncome/Income Avg 2.csv")
income_inequality = pd.read_csv("/Users/lorenzmaresca/Desktop/Greg/GregDiss/Data/WealthIncome/Income Inequality.csv")
income_inequality_2 = pd.read_csv("/Users/lorenzmaresca/Desktop/Greg/GregDiss/Data/WealthIncome/Income Inequality 2.csv")
avg_wealth_total = pd.read_csv("/Users/lorenzmaresca/Desktop/Greg/GregDiss/Data/WealthIncome/Avg Wealth.csv")
avg_wealth_total_2 = pd.read_csv("/Users/lorenzmaresca/Desktop/Greg/GregDiss/Data/WealthIncome/Avg Wealth 2.csv")
wealth_inequality = pd.read_csv("/Users/lorenzmaresca/Desktop/Greg/GregDiss/Data/WealthIncome/Wealth Inequality.csv")
wealth_inequality_2 = pd.read_csv("/Users/lorenzmaresca/Desktop/Greg/GregDiss/Data/WealthIncome/Wealth Inequality 2.csv")

# %% [markdown]
# ## 2.1 Displaying Datasets

# %% [markdown]
# ### 2.1.1 Income

# %%
income_inequality.head()
# Out:
#   Percentile  Year  pretaxincome_over_total_pretax_income  mean_percentile
# 0    p90p100  1961                               0.256517         0.327409
# 1    p90p100  1962                               0.256517         0.327409
# 2    p90p100  1963                               0.256517         0.327409
# 3    p90p100  1964                               0.246366         0.327409
# 4    p90p100  1965                               0.246366         0.327409

# %%
income_inequality_2.head()
# Out:
#    Year  Pre-tax nationa income (p90p100)  Pre-tax nationa income (50p90p)  \
# 0  1961                          0.256517                         0.483588
# 1  1962                          0.256517                         0.483588
# 2  1963                          0.256517                         0.483588
# 3  1964                          0.246366                         0.480572
# 4  1965                          0.246366                         0.480572
#
#    Pre-tax nationa income (0p50p)  Pre-tax nationa income (99p100p)
# 0                        0.259895                          0.044800
# 1                        0.259895                          0.044800
# 2                        0.259895                          0.044800
# 3                        0.273062                          0.043029
# 4                        0.273062                          0.043029

# %%
avg_income_total.head()
# Out:
#   Percentaile  Year  avg_pre_tax_income
# 0     p99p100  1961         1321924.625
# 1     p99p100  1962         1321924.625
# 2     p99p100  1963         1321924.625
# 3     p99p100  1964         1443913.125
# 4     p99p100  1965         1443913.125

# %%
avg_income_total_2.head()
# Out:
#    Year  avg_pre_tax_income (p99p100)  avg_pre_tax_income (p90p100)  \
# 0  1961                   1321924.625                   756903.9375
# 1  1962                   1321924.625                   756903.9375
# 2  1963                   1321924.625                   756903.9375
# 3  1964                   1443913.125                   826726.8750
# 4  1965                   1443913.125                   826726.8750
#
#    avg_pre_tax_income (p50p90)  avg_pre_tax_income (p0p50)  \
# 0                  356730.9063                 153374.7813
# 1                  356730.9063                 153374.7813
# 2                  356730.9063                 153374.7813
# 3                  403162.1875                 183262.3594
# 4                  403162.1875                 183262.3594
#
#    avg_pre_tax_income (p0p100)
# 0                  295070.1250
# 1                  312310.3125
# 2                  318720.9375
# 3                  335568.7500
# 4                  346440.2188

# %% [markdown]
# ### 2.1.2 Wealth

# %%
wealth_inequality.head()
# Out:
#   Percentile  Year  rel_pct_share_of_national_wealth
# 0    p99p100  1995                          0.215031
# 1    p99p100  1996                          0.234242
# 2    p99p100  1997                          0.315070
# 3    p99p100  1998                          0.357450
# 4    p99p100  1999                          0.412466

# %%
wealth_inequality_2.head()
# Out:
#    Year  Private Wealth/GDP\nTop 1%\n  Private Wealth/GDP\nTop 10%\n  \
# 0  1995                      0.215031                       0.525537
# 1  1996                      0.234242                       0.544091
# 2  1997                      0.315070                       0.595654
# 3  1998                      0.357450                       0.624042
# 4  1999                      0.412466                       0.657416
#
#    Private Wealth/GDP\nMid 40%\n  Private Wealth/GDP\nBottom 40%\n
# 0                       0.389020                          0.085443
# 1                       0.374247                          0.081662
# 2                       0.333037                          0.071308
# 3                       0.309800                          0.066158
# 4                       0.281783                          0.060801

# %%
avg_wealth_total.head()
# Out:
#   Percentile  Year  avg_private_wealth
# 0    p90p100  1990           3597809.5
# 1    p90p100  1991           3597809.5
# 2    p90p100  1992           3597809.5
# 3    p90p100  1993           3597809.5
# 4    p90p100  1994           3597809.5

# %%
avg_wealth_total_2.head()
# Out:
#   Percentile  Year  avg_private_wealth (p99p100)  \
# 0    p90p100  1990                    14720980.0
# 1    p90p100  1991                    14720980.0
# 2    p90p100  1992                    14720980.0
# 3    p90p100  1993                    14720980.0
# 4    p90p100  1994                    14720980.0
#
#    avg_private_wealth (p90p100)  avg_private_wealth (p50p90)  \
# 0                     3597809.5                    665805.81
# 1                     3597809.5                    665805.81
# 2                     3597809.5                    665805.81
# 3                     3597809.5                    665805.81
# 4                     3597809.5                    665805.81
#
#    avg_private_wealth (p0p50)  avg_private_wealth (p0p100)
# 0                   116988.09                   2048447.13
# 1                   116988.09                    568290.63
# 2                   116988.09                    589885.63
# 3                   116988.09                    630599.31
# ...

# %% [markdown]
# # 3. Visualising the Data - PreTax Income

# %% [markdown]
# ### 3.1 Frequency Distribution - Relative Pct. Share of Total

# %%
ax = sns.kdeplot(income_inequality['pretaxincome_over_total_pretax_income'] , shade = True)
plt.axvline(income_inequality['pretaxincome_over_total_pretax_income'].mean(), linestyle = "--" , color = "red", label = "Mean")
plt.axvline(income_inequality['pretaxincome_over_total_pretax_income'].median(), linestyle = "--" , color = "green", label = "Median")

vals = ax.get_xticks()
ax.set_xticklabels(['{:20,.2f}'.format(x) for x in vals]) 
valsy = ax.get_yticks()
ax.set_yticklabels(['{:20,.2f}'.format(x) for x in valsy]) 

plt.legend(loc='best', bbox_to_anchor=(1.3, 0.5, 0.5, 0.5))

plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### 3.2 Frequency Distribution - Relative Pct. Share of Total by Strata

# %%
mean_p99 = income_inequality[income_inequality["Percentile"] == "p99p100"].iloc[1,3]
mean_p90 = income_inequality[income_inequality["Percentile"] == "p90p100"].iloc[1,3]
mean_p50 = income_inequality[income_inequality["Percentile"] == "50p90p"].iloc[1,3]
mean_p0 = income_inequality[income_inequality["Percentile"] == "0p50p"].iloc[1,3]

# %%
g = sns.FacetGrid(income_inequality,  hue = "Percentile", size=4.5, aspect=2)
g.map(plt.axvline, x = mean_p99, ls=":", color = "red")
g.map(plt.axvline, x = mean_p90, ls=":", color = "lightblue" , linewidth = 2.5)
g.map(plt.axvline, x = mean_p50, ls=":", color = "yellow")
g.map(plt.axvline, x = mean_p0, ls=":", color = "green")
g.map(sns.kdeplot, "pretaxincome_over_total_pretax_income" , shade = True)


g.add_legend()
plt.show();
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
inc_ine = income_inequality.copy()
inc_ine["mean"] = inc_ine["pretaxincome_over_total_pretax_income"].mean()
inc_ine.head()
# Out:
#   Percentile  Year  pretaxincome_over_total_pretax_income  mean_percentile  \
# 0    p90p100  1961                               0.256517         0.327409
# 1    p90p100  1962                               0.256517         0.327409
# 2    p90p100  1963                               0.256517         0.327409
# 3    p90p100  1964                               0.246366         0.327409
# 4    p90p100  1965                               0.246366         0.327409
#
#        mean
# 0  0.277603
# 1  0.277603
# 2  0.277603
# 3  0.277603
# 4  0.277603

# %%
g = sns.FacetGrid(inc_ine,  col = "Percentile", legend_out = False, size= 4)
g.map(sns.kdeplot, "pretaxincome_over_total_pretax_income" , shade = True)
plt.xticks(np.arange(0, 1, step=0.15))
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### 3.3 Time-Series Analysis - Relative Pct. Share of Total by Strata

# %%
sns.set(style='ticks')
ax = income_inequality_2.plot(kind = "line" , x = "Year" ,xlim = (1960,2014) ,  
                         linestyle='-', 
                         linewidth=2.5, 
                         drawstyle ="steps-post", 
                         marker = "." ,
                         markersize=10)

plt.axhline(mean_p99, color = "purple", linestyle = "dotted" , linewidth = 1)
plt.axhline(mean_p90, color = "blue", linestyle = "dotted" , linewidth = 1)
plt.axhline(mean_p50, color = "green", linestyle = "dotted" , linewidth = 1)
plt.axhline(mean_p0, color = "red", linestyle = "dotted" , linewidth = 1)

vals = ax.get_yticks()
ax.set_yticklabels(['{:,.2%}'.format(x) for x in vals])


ax.legend(loc='best', bbox_to_anchor=(1, 0.5, 0.5, 0.5))

# %% [markdown]
# ### 3.4 CAGR (Cummulative Annual Growth Rates) - Relative Pct. Share of Total by Strata

# %%
CAGR = ((income_inequality_2.loc[54,] / income_inequality_2.loc[0,]) **(1/len(income_inequality_2)) -1) * 100
pd.DataFrame(CAGR).drop("Year", 0).rename(columns = {0: "CAGR (Cummulative Annual Growth Rates) by Strata 1961 - 2014"})
# Out:
#                                   CAGR (Cummulative Annual Growth Rates) by Strata 1961 - 2014
# Pre-tax nationa income (p90p100)                                           1.048181
# Pre-tax nationa income (50p90p)                                           -0.461694
# Pre-tax nationa income (0p50p)                                            -0.769875
# Pre-tax nationa income (99p100p)                                           2.779489

# %% [markdown]
# ### 3.5 Frequency Distribution - Nominal Values in Rubles

# %%
ax = sns.kdeplot(avg_income_total['avg_pre_tax_income'] , shade = True)

plt.axvline(avg_income_total['avg_pre_tax_income'].mean(), linestyle = "--" , color = "blue" , label = "Mean")
plt.axvline(avg_income_total['avg_pre_tax_income'].median(), linestyle = "--" , color = "green" ,label = "Meadian")

vals = ax.get_xticks()
ax.set_xticklabels(['{:20,.2f}'.format(x) for x in vals], rotation = 70) 
valsy = ax.get_yticks()
ax.set_yticklabels(['{:20,.7f}'.format(x) for x in valsy]) 

plt.legend(loc='best', bbox_to_anchor=(0.95, 0.5, 0.5, 0.5))


plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### 3.6 Frequency Distribution - Nominal Values in Rubles by Strata

# %%
strat_1 = avg_income_total[avg_income_total["Percentaile"] == "p99p100"]
strat_2 = avg_income_total[avg_income_total["Percentaile"] == "p90p100"]
strat_3 = avg_income_total[avg_income_total["Percentaile"] == "p50p90"]
strat_4 = avg_income_total[avg_income_total["Percentaile"] == "p0p50"]

# %%
g = sns.FacetGrid(avg_income_total,  hue = "Percentaile", size=5, aspect=2)
g.map(plt.axvline, x = strat_1["avg_pre_tax_income"].mean(), ls=":", color = "red")
g.map(plt.axvline, x = strat_2["avg_pre_tax_income"].mean(), ls=":", color = "lightblue" , linewidth = 2.5)
g.map(plt.axvline, x = strat_3["avg_pre_tax_income"].mean(), ls=":", color = "yellow")
g.map(plt.axvline, x = strat_4["avg_pre_tax_income"].mean(), ls=":", color = "green")
g.map(sns.kdeplot, "avg_pre_tax_income" , shade = True)


g.add_legend()
plt.show();
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
gt = sns.FacetGrid(avg_income_total,  col = "Percentaile" ,  col_wrap=5, size= 5, aspect = 0.6)
gt.map(plt.axhline, y= "avg_pre_tax_income", ls=":", color = "black")
gt.map(sns.kdeplot, "avg_pre_tax_income" , 
                         marker = "." , 
                         linewidth=1, 
                         markersize=5,
                         drawstyle ="steps", 
                         color = "green")


plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### 3.7 Time-Series Analysis - Nominal Values in Rubles by Strata

# %%
gt = sns.FacetGrid(avg_income_total,  col = "Percentaile" ,  col_wrap=5, size= 10, aspect = 0.4)
gt.map(plt.axhline, y= "avg_pre_tax_income", ls=":", color = "black")
gt.map(plt.plot,"Year" , "avg_pre_tax_income" , 
                         marker = "." , 
                         linewidth=1, 
                         markersize=5,
                         drawstyle ="steps", 
                         color = "green")


plt.show()

# %%
avg_meanp99 = avg_income_total_2["avg_pre_tax_income (p99p100)"].mean()
avg_meanp90 = avg_income_total_2["avg_pre_tax_income (p90p100)"].mean()
avg_meanp50 = avg_income_total_2["avg_pre_tax_income (p50p90)"].mean()
avg_meanp0 = avg_income_total_2["avg_pre_tax_income (p0p50)"].mean()

# %%
sns.set(style='ticks')
ax = avg_income_total_2.plot(kind = "line" , x = "Year" ,xlim = (1960,2014) , 
                         marker = "." , 
                         linestyle='-', 
                         linewidth=2, 
                         markersize=10,
                         drawstyle ="steps")

plt.axhline(avg_meanp99, color = "blue", linestyle = "dotted" , linewidth = 1)
plt.axhline(avg_meanp90, color = "green", linestyle = "dotted" , linewidth = 1)
plt.axhline(avg_meanp50, color = "red", linestyle = "dotted" , linewidth = 1)
plt.axhline(mean_p0, color = "purple", linestyle = "dotted" , linewidth = 1)

vals = ax.get_yticks()
ax.set_yticklabels(['{:20,.2f}'.format(x) for x in vals]) 
ax.legend (loc='best', bbox_to_anchor=(1, 0.5, 0.5, 0.5))

# %% [markdown]
# ### 3.8 CAGR (Cummulative Annual Growth Rates) - Nominal Values in Rubles by Strata

# %%
CAGR = ((avg_income_total_2.loc[54,] / avg_income_total_2.loc[0,]) **(1/len(avg_income_total_2)) -1) * 100
pd.DataFrame(CAGR).drop("Year", 0).rename(columns = {0: "CAGR (Cummulative Annual Growth Rates) by Strata 1961 - 2014"})
# Out:
#                               CAGR (Cummulative Annual Growth Rates) by Strata 1961 - 2014
# avg_pre_tax_income (p99p100)                                           4.366592
# avg_pre_tax_income (p90p100)                                           2.608550
# avg_pre_tax_income (p50p90)                                            1.075359
# avg_pre_tax_income (p0p50)                                             0.762420
# avg_pre_tax_income (p0p100)                                            1.544183

# %% [markdown]
# ### 3.9 CAGR (Cummulative Annual Growth Rates) - Nominal Values in Rubles by Strata (1990 - 2014)

# %%
break_df = avg_income_total_2[avg_income_total_2["Year"] >= 1990]
CAGR_nom = ((break_df.loc[54,] / break_df.loc[29,]) **(1/len(break_df)) -1) * 100
pd.DataFrame(CAGR_nom).drop("Year", 0).rename(columns = {0: "CAGR (Cummulative Annual Growth Rates) by Strata 1990 - 2014"})
# Out:
#                               CAGR (Cummulative Annual Growth Rates) by Strata 1990 - 2014
# avg_pre_tax_income (p99p100)                                           4.650072
# avg_pre_tax_income (p90p100)                                           3.222868
# avg_pre_tax_income (p50p90)                                           -0.222549
# avg_pre_tax_income (p0p50)                                            -1.465232
# avg_pre_tax_income (p0p100)                                            0.644406

# %% [markdown]
# ### 3.10 CAGR (Cummulative Annual Growth Rates) - Nominal Values in Rubles by Strata (1961 - 1990)

# %%
break_df = avg_income_total_2[avg_income_total_2["Year"] <= 1990]
CAGR_nom = ((break_df.loc[28,] / break_df.loc[0,]) **(1/len(break_df)) -1) * 100
pd.DataFrame(CAGR_nom).drop("Year", 0).rename(columns = {0: "CAGR (Cummulative Annual Growth Rates) by Strata 1961 - 1990"})
# Out:
#                               CAGR (Cummulative Annual Growth Rates) by Strata 1961 - 1990
# avg_pre_tax_income (p99p100)                                           3.009627
# avg_pre_tax_income (p90p100)                                           2.105076
# avg_pre_tax_income (p50p90)                                            2.211334
# avg_pre_tax_income (p0p50)                                             2.877259
# avg_pre_tax_income (p0p100)                                            2.371263

# %% [markdown]
# # 4. Visualising the Data - Net Private Wealth

# %% [markdown]
# ### 4.2 Frequency Distribution - Relative Pct. Share of Total

# %%
wealth_inequality.rename( columns = {"%_private_wealth_over_gdp": "rel_pct_share_of_national_wealth"}, inplace = True)
# Out:
#   Percentile  Year  rel_pct_share_of_national_wealth
# 0    p99p100  1995                          0.215031
# 1    p99p100  1996                          0.234242
# 2    p99p100  1997                          0.315070
# 3    p99p100  1998                          0.357450
# 4    p99p100  1999                          0.412466

# %%
ax = sns.kdeplot(wealth_inequality['rel_pct_share_of_national_wealth'] , shade=True) #### Rename "total share of private wealth"
plt.axvline(wealth_inequality['rel_pct_share_of_national_wealth'].mean(), linestyle = "--" , color = "blue")
plt.axvline(wealth_inequality['rel_pct_share_of_national_wealth'].median(), linestyle = "--" , color = "blue")

vals = ax.get_xticks()
ax.set_xticklabels(['{:20,.2f}'.format(x) for x in vals]) 
valsy = ax.get_yticks()
ax.set_yticklabels(['{:20,.2f}'.format(x) for x in valsy]) 

plt.legend(loc='best', bbox_to_anchor=(1.05, 0.5, 0.5, 0.5))

plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### 4.2 Frequency Distribution - Relative Pct. Share of Total by Strata

# %%
strat_1 = wealth_inequality[wealth_inequality["Percentile"] == "p99p100"]
strat_2 = wealth_inequality[wealth_inequality["Percentile"] == "p90p100"]
strat_3 = wealth_inequality[wealth_inequality["Percentile"] == "p50p90"]
strat_4 = wealth_inequality[wealth_inequality["Percentile"] == "p0p50"]
strat_5 = wealth_inequality[wealth_inequality["Percentile"] == "p0p100"]

# %%
g = sns.FacetGrid(wealth_inequality,  hue = "Percentile", size=5, aspect=2)
g.map(plt.axvline, x = strat_1["rel_pct_share_of_national_wealth"].mean(), ls=":", color = "blue")
g.map(plt.axvline, x = strat_2["rel_pct_share_of_national_wealth"].mean(), ls=":", color = "yellow" , linewidth = 2.5)
g.map(plt.axvline, x = strat_3["rel_pct_share_of_national_wealth"].mean(), ls=":", color = "green")
g.map(plt.axvline, x = strat_4["rel_pct_share_of_national_wealth"].mean(), ls=":", color = "red")
g.map(sns.kdeplot, "rel_pct_share_of_national_wealth" , shade = True)


g.add_legend()
plt.show();
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
gw = sns.FacetGrid(wealth_inequality,  col = "Percentile", size=5, aspect=0.6)
gw.map(sns.kdeplot, "rel_pct_share_of_national_wealth" , shade = True)
plt.xticks(np.arange(0, 1, step=0.15))
gw.add_legend()
plt.show();
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### 4.3 Net Private Wealth - Time-Series Analysis - Relative Pct. Share of Total by Strata

# %%
sns.set(style='ticks')
plot_wealth = wealth_inequality_2.plot(kind = "line" , x = "Year" , 
                         marker = "." , 
                         linestyle='-', 
                         linewidth=2, 
                         markersize=10,
                         drawstyle ="steps")



plt.axhline(strat_1["rel_pct_share_of_national_wealth"].mean(), color = "blue", linestyle = "dotted" , linewidth = 1)
plt.axhline(strat_2["rel_pct_share_of_national_wealth"].mean(), color = "green", linestyle = "dotted" , linewidth = 1)
plt.axhline(strat_3["rel_pct_share_of_national_wealth"].mean(), color = "red", linestyle = "dotted" , linewidth = 1)
plt.axhline(strat_4["rel_pct_share_of_national_wealth"].mean(), color = "purple", linestyle = "dotted" , linewidth = 1)


plot_wealth.legend(loc='best', bbox_to_anchor=(1, 0.5, 0.5, 0.5)) ###Need to change the x values from the csv

# %% [markdown]
# ### 4.4 Frequency Distribution - Nominal Values in Rubles

# %%
ax = sns.kdeplot(avg_wealth_total['avg_private_wealth'] , shade = True)
plt.axvline(avg_wealth_total['avg_private_wealth'].mean(), linestyle = "--" , color = "blue")
plt.axvline(avg_wealth_total['avg_private_wealth'].median(), linestyle = "--" , color = "darkblue")

vals = ax.get_xticks()
ax.set_xticklabels(['{:20,.2f}'.format(x) for x in vals], rotation = 70) 

valsy = ax.get_yticks()
ax.set_yticklabels(['{:20,.8f}'.format(x) for x in valsy]) 

plt.legend(loc='best', bbox_to_anchor=(0.95, 0.5, 0.5, 0.5))

plt.show()

# %% [markdown]
# ### 4.5 Frequency Distribution - Nominal Values in Rubles by Strata

# %%
strat_1 = avg_wealth_total[avg_wealth_total["Percentile"] == "p99p100"]
strat_2 = avg_wealth_total[avg_wealth_total["Percentile"] == "p90p100"]
strat_3 = avg_wealth_total[avg_wealth_total["Percentile"] == "p50p90"]
strat_4 = avg_wealth_total[avg_wealth_total["Percentile"] == "p0p50"]
strat_5 = avg_wealth_total[avg_wealth_total["Percentile"] == "p0p100"]

# %%
g = sns.FacetGrid(avg_wealth_total,  hue = "Percentile", size=7, aspect=2)
g.map(plt.axvline, x = strat_1["avg_private_wealth"].mean(), ls=":", color = "red")
g.map(plt.axvline, x = strat_2["avg_private_wealth"].mean(), ls=":", color = "lightblue" , linewidth = 2.5)
g.map(plt.axvline, x = strat_3["avg_private_wealth"].mean(), ls=":", color = "yellow")
g.map(plt.axvline, x = strat_4["avg_private_wealth"].mean(), ls=":", color = "green")
g.map(plt.axvline, x = strat_4["avg_private_wealth"].mean(), ls=":", color = "green")
g.map(sns.kdeplot, "avg_private_wealth" , shade = True)


g.add_legend()
plt.show();
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
gt = sns.FacetGrid(avg_wealth_total,  col = "Percentile" ,  col_wrap=5, size = 6.5, aspect = 0.5)
gt.map(plt.axhline, y= "avg_private_wealth", ls=":", c=".5")
gt.map(sns.kdeplot,  "avg_private_wealth" , 
                         marker = "." , 
                         linewidth=1, 
                         markersize=5,
                         drawstyle ="steps", 
                         color = "green")
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### 4.6 Net Private Wealth - Time-Series Analysis - Nominal Values in Rubles by Strata

# %%
gt = sns.FacetGrid(avg_wealth_total,  col = "Percentile" ,  col_wrap=5, size = 6.5, aspect = 0.5)
gt.map(plt.axhline, y= "avg_private_wealth", ls=":", c=".5")
gt.map(plt.plot, "Year", "avg_private_wealth" , 
                         marker = "." , 
                         linewidth=1, 
                         markersize=5,
                         drawstyle ="steps", 
                         color = "green")
plt.show()

# %%
plot_wealth = avg_wealth_total_2.plot(kind = "line" , x = "Year",  
                         linestyle='-', 
                         linewidth=2.5, 
                         drawstyle ="steps-post", 
                         marker = "." ,
                         markersize=10)


plt.axhline(strat_1["avg_private_wealth"].mean(), color = "blue", linestyle = "dotted" , linewidth = 1)
plt.axhline(strat_2["avg_private_wealth"].mean(), color = "green", linestyle = "dotted" , linewidth = 1)
plt.axhline(strat_3["avg_private_wealth"].mean(), color = "red", linestyle = "dotted" , linewidth = 1)
plt.axhline(strat_4["avg_private_wealth"].mean(), color = "purple", linestyle = "dotted" , linewidth = 1)

valsy = plot_wealth.get_yticks()
plot_wealth.set_yticklabels(['{:20,.2f}'.format(x) for x in vals])

plot_wealth.legend (loc='best', bbox_to_anchor=(1.1, 0.5, 0.5, 0.5))
